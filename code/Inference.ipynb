# %%
# !pip install -U ultralytics
import ultralytics
ultralytics.checks()  # Verify setup
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 38.2/112.6 GB disk)

# %%
import os
import json
from tqdm import tqdm

import json
from collections import defaultdict
from ultralytics import YOLO

# %% [markdown]
# # Inferencing

# %%
MODEL_PATH = '/content/drive/MyDrive/ZALO_AI/1st_version/yolo_dataset/yolo11sZalo/train/weights/best.pt'

TEST_DATA_DIR = '/content/drive/MyDrive/ZALO_AI/public_test/samples'

OUTPUT_FILE = 'yolo11s_zalo.json'

CONFIDENCE_THRESHOLD = 0.25

# %%
def run_inference():
    """
    Run YOLO11 on test videos and write detections to JSON.
    """

    # load trained model
    try:
        model = YOLO(MODEL_PATH)
        print(f"Successfully loaded model from {MODEL_PATH}")
    except Exception as e:
        print(f"Error: Could not load model from {MODEL_PATH}")
        print(e)
        return

    all_predictions = []

    # list video folders
    try:
        video_folders = sorted([f for f in os.listdir(TEST_DATA_DIR) if os.path.isdir(os.path.join(TEST_DATA_DIR, f))])
    except FileNotFoundError:
        print(f"Error: Test data directory not found at: {TEST_DATA_DIR}")
        return

    if not video_folders:
        print(f"Error: No video folders found in {TEST_DATA_DIR}")
        return

    print(f"Found {len(video_folders)} videos to process...")

    for video_folder_name in tqdm(video_folders, desc="Processing videos"):
        video_path = os.path.join(TEST_DATA_DIR, video_folder_name, 'drone_video.mp4')

        if not os.path.exists(video_path):
            print(f"Warning: 'drone_video.mp4' not found in {video_folder_name}, skipping.")
            continue

        video_bboxes = []

        try:
            # predict on the video
            results_generator = model.predict(
                video_path,
                stream=True,
                conf=CONFIDENCE_THRESHOLD,
                verbose=False
            )

            # iterate frames
            for frame_idx, results in enumerate(results_generator):

                # bounding boxes in [x1, y1, x2, y2]
                xyxy_boxes = results.boxes.xyxy.cpu().numpy()

                if len(xyxy_boxes) == 0:
                    continue

                # loop each detection
                for box in xyxy_boxes:
                    x1, y1, x2, y2 = box

                    # build bbox dict
                    bbox_data = {
                        "frame": frame_idx,
                        "x1": int(round(x1)),
                        "y1": int(round(y1)),
                        "x2": int(round(x2)),
                        "y2": int(round(y2))
                    }
                    video_bboxes.append(bbox_data)

        except Exception as e:
            print(f"Error while processing video {video_path}: {e}")
            continue 

        # Build JSON structure
        # Format: detections -> list of {bboxes}
        detections_list = []
        if len(video_bboxes) > 0:
            # Add detections if present
            detections_list.append({"bboxes": video_bboxes})
        
        final_video_obj = {
            "video_id": video_folder_name,
            "detections": detections_list
        }
        all_predictions.append(final_video_obj)

    # save merged predictions
    try:
        print(f"\nSaving all {len(all_predictions)} video predictions to {OUTPUT_FILE}...")
        with open(OUTPUT_FILE, 'w') as f:
            json.dump(all_predictions, f, indent=4)
        print("Inference complete.")
    except Exception as e:
        print(f"Error: Could not write output JSON file: {e}")

if __name__ == "__main__":
    run_inference()
# Out:
# Successfully loaded model from /content/drive/MyDrive/ZALO_AI/1st_version/yolo_dataset/yolo11sZalo/train2/weights/best.pt
# Found 6 videos to process...
# Processing videos: 100%|██████████| 6/6 [09:24<00:00, 94.05s/it]
# Saving all 6 video predictions to yolo11s_zalo.json...
# Inference complete.

# %% [markdown]
# # Inference with tracker

# %%
DATASET_ROOT = "/content/drive/MyDrive/ZALO_AI/public_test/samples"
OUTPUT_FILE = "yolo11s_track_zalo.json"
MODEL_WEIGHTS = "/content/drive/MyDrive/ZALO_AI/1st_version/yolo_dataset/yolo11sZalo/train/weights/best.pt"

def process_dataset():
    # 1) load model
    model = YOLO(MODEL_WEIGHTS)

    # hold all video outputs
    all_videos_output = []

    # 2) find video folders (under samples/, sorted for consistency)
    if not os.path.exists(DATASET_ROOT):
        print(f"Error: Dataset root '{DATASET_ROOT}' not found.")
        return

    video_folders = sorted(os.listdir(DATASET_ROOT))

    print(f"Found {len(video_folders)} folders. Starting processing...")

    # 3) iterate through each folder
    for folder_name in tqdm(video_folders):
        video_path = os.path.join(DATASET_ROOT, folder_name, "drone_video.mp4")

        # skip if the video file doesn't exist
        if not os.path.exists(video_path):
            continue

        # folder name is the video_id (e.g., "drone_video_001")
        video_id = folder_name

        results = model.track(source=video_path, conf=0.3, iou=0.5, stream=True, verbose=False)

        track_history = defaultdict(list)

        for frame_index, r in enumerate(results):
            if r.boxes and r.boxes.id is not None:
                boxes = r.boxes.xyxy.int().cpu().tolist()
                track_ids = r.boxes.id.int().cpu().tolist()

                for track_id, box in zip(track_ids, boxes):
                    x1, y1, x2, y2 = box

                    bbox_entry = {
                        "frame": frame_index,
                        "x1": x1,
                        "y1": y1,
                        "x2": x2,
                        "y2": y2
                    }
                    track_history[track_id].append(bbox_entry)

        detections_list = []
        for track_id, bboxes in track_history.items():
            detections_list.append({
                "bboxes": bboxes
            })

        # append to dataset output
        all_videos_output.append({
            "video_id": video_id,
            "detections": detections_list
        })

    # 4) save merged JSON
    with open(OUTPUT_FILE, "w") as f:
        json.dump(all_videos_output, f, indent=3)

    print(f"\nProcessing complete! Results saved to {OUTPUT_FILE}")

process_dataset()
# Out:
# Found 6 folders. Starting processing...
# 100%|██████████| 6/6 [21:24<00:00, 214.08s/it]
# Processing complete! Results saved to yolo11s_track_zalo.json

# %% [markdown]
# # Visualize output

# %%
model = YOLO("/content/drive/MyDrive/ZALO_AI/VisDrone_val_Yolo/yolo11s/train/weights/best.pt")

results_generator = model.track(
    source="/content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4",
    conf=0.3,
    iou=0.5,
    save=True,
    stream=True
)

for r in results_generator:
    pass
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (frame 5469/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5470/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5471/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5472/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.1ms
# video 1/1 (frame 5473/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5474/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5475/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5476/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.0ms
# video 1/1 (frame 5477/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5478/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5479/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5480/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5481/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5482/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.3ms
# video 1/1 (frame 5483/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5484/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5485/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5486/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5487/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5488/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5489/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5490/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5491/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5492/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5493/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5494/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5495/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5496/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5497/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.1ms
# video 1/1 (frame 5498/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5499/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5500/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5501/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5502/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5503/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5504/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5505/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5506/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5507/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5508/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5509/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5510/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5511/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5512/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5513/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5514/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5515/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.0ms
# video 1/1 (frame 5516/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5517/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5518/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5519/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5520/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5521/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5522/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5523/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5524/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5525/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5526/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5527/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5528/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5529/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5530/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5531/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5532/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5533/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5534/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5535/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 5536/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5537/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.2ms
# video 1/1 (frame 5538/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5539/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5540/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5541/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5542/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5543/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5544/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5545/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5546/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5547/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5548/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5549/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5550/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5551/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5552/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5553/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5554/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5555/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5556/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5557/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5558/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5559/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5560/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 5561/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5562/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5563/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5564/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5565/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5566/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5567/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 5568/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5569/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5570/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5571/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.1ms
# video 1/1 (frame 5572/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.1ms
# video 1/1 (frame 5573/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5574/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5575/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5576/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5577/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5578/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.3ms
# video 1/1 (frame 5579/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5580/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5581/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5582/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5583/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5584/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5585/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5586/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5587/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5588/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 5589/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5590/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.2ms
# video 1/1 (frame 5591/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5592/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5593/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5594/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5595/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5596/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5597/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5598/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5599/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5600/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5601/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5602/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5603/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5604/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5605/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5606/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.3ms
# video 1/1 (frame 5607/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5608/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5609/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.1ms
# video 1/1 (frame 5610/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5611/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.6ms
# video 1/1 (frame 5612/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5613/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5614/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5615/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5616/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5617/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5618/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5619/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5620/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5621/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5622/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5623/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.3ms
# video 1/1 (frame 5624/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5625/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 5626/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5627/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.2ms
# video 1/1 (frame 5628/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 5629/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.0ms
# video 1/1 (frame 5630/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5631/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5632/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.1ms
# video 1/1 (frame 5633/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5634/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5635/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5636/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5637/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5638/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5639/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5640/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5641/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5642/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5643/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5644/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5645/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5646/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5647/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.7ms
# video 1/1 (frame 5648/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5649/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5650/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5651/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5652/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.0ms
# video 1/1 (frame 5653/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5654/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5655/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5656/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5657/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5658/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5659/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5660/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5661/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5662/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5663/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5664/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5665/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5666/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5667/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5668/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5669/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5670/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5671/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5672/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5673/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5674/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5675/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 5676/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5677/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5678/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5679/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 5680/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5681/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5682/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5683/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5684/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5685/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5686/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5687/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5688/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5689/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5690/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.7ms
# video 1/1 (frame 5691/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5692/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5693/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.3ms
# video 1/1 (frame 5694/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5695/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5696/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5697/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5698/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5699/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5700/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5701/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5702/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5703/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5704/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5705/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5706/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5707/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 5708/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 5709/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5710/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5711/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5712/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 5713/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 5714/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5715/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5716/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5717/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5718/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5719/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5720/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5721/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5722/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5723/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.2ms
# video 1/1 (frame 5724/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.9ms
# video 1/1 (frame 5725/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5726/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5727/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5728/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5729/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5730/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5731/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5732/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5733/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5734/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5735/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5736/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5737/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5738/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5739/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5740/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5741/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5742/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5743/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5744/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5745/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5746/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5747/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5748/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5749/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5750/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5751/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5752/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5753/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5754/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.1ms
# video 1/1 (frame 5755/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 5756/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 5757/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5758/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5759/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5760/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5761/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5762/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5763/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5764/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.7ms
# video 1/1 (frame 5765/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5766/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5767/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5768/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.6ms
# video 1/1 (frame 5769/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 5770/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5771/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5772/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.3ms
# video 1/1 (frame 5773/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5774/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5775/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5776/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5777/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5778/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5779/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5780/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 5781/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5782/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5783/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 13.4ms
# video 1/1 (frame 5784/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5785/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# video 1/1 (frame 5786/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5787/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5788/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5789/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.2ms
# video 1/1 (frame 5790/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5791/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5792/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 5793/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5794/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 5795/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5796/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.3ms
# video 1/1 (frame 5797/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 5798/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5799/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5800/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5801/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 5802/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5803/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5804/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5805/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5806/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.8ms
# video 1/1 (frame 5807/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 5808/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5809/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5810/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5811/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5812/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5813/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 5814/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 5815/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5816/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5817/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5818/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5819/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 5820/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5821/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 5822/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5823/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 5824/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5825/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5826/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 5827/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.5ms
# ...
# video 1/1 (frame 10349/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10350/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.0ms
# video 1/1 (frame 10351/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10352/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10353/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10354/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10355/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10356/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10357/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10358/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10359/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10360/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 10361/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10362/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10363/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10364/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10365/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10366/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10367/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10368/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10369/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 10370/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 10371/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 10372/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10373/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10374/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10375/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 10376/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10377/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10378/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10379/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.0ms
# video 1/1 (frame 10380/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.4ms
# video 1/1 (frame 10381/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 10382/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10383/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10384/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10385/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 10386/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10387/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10388/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 10389/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10390/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10391/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10392/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 10393/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 10394/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 10395/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 10396/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10397/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 10398/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 10399/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10400/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 10401/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10402/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10403/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 10404/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.4ms
# video 1/1 (frame 10405/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10406/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10407/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10408/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10409/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.9ms
# video 1/1 (frame 10410/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.0ms
# video 1/1 (frame 10411/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 10412/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.3ms
# video 1/1 (frame 10413/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10414/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10415/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 10416/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.4ms
# video 1/1 (frame 10417/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.8ms
# video 1/1 (frame 10418/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10419/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10420/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10421/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10422/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 12.6ms
# video 1/1 (frame 10423/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 10424/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10425/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 10426/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10427/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10428/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10429/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.1ms
# video 1/1 (frame 10430/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10431/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.1ms
# video 1/1 (frame 10432/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10433/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 10434/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10435/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10436/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10437/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10438/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10439/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 1 object, 11.8ms
# video 1/1 (frame 10440/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.7ms
# video 1/1 (frame 10441/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10442/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10443/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10444/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.6ms
# video 1/1 (frame 10445/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 10446/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.3ms
# video 1/1 (frame 10447/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10448/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 11.2ms
# video 1/1 (frame 10449/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.5ms
# video 1/1 (frame 10450/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10451/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10452/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.7ms
# video 1/1 (frame 10453/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10454/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.1ms
# video 1/1 (frame 10455/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.6ms
# video 1/1 (frame 10456/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.4ms
# video 1/1 (frame 10457/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 10458/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 10459/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.9ms
# video 1/1 (frame 10460/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.5ms
# video 1/1 (frame 10461/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# video 1/1 (frame 10462/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.8ms
# video 1/1 (frame 10463/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10464/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.2ms
# video 1/1 (frame 10465/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 10.2ms
# video 1/1 (frame 10466/10466) /content/drive/MyDrive/ZALO_AI/train/samples/Backpack_0/drone_video.mp4: 544x960 (no detections), 9.7ms
# Speed: 3.7ms preprocess, 9.8ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 960)
# Results saved to /content/runs/detect/track
